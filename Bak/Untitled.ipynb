# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.Graph()
G.add_nodes_from(['가','나','다','라'])
G.add_edges_from([('가','나'),('가','나'),('가','다'),('나','다')
,('나','다'),('나','다'),('다','라')])
nx.draw(G)#, with_labels=True)
plt.show()
